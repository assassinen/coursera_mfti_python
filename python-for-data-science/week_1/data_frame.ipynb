# %%
import pandas as pd
import numpy as np
from geopy.distance import vincenty

# %%
df.shape
# Out:
# (1877884, 15)

# %%
data = ['20:00']
dataframe = pd.DataFrame(data)

# %%
df
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                1635  2018-09-01 00:00:05.2690  2018-09-01 00:27:20.6340
# 1                 132  2018-09-01 00:00:11.2810  2018-09-01 00:02:23.4810
# 2                3337  2018-09-01 00:00:20.6490  2018-09-01 00:55:58.5470
# 3                 436  2018-09-01 00:00:21.7460  2018-09-01 00:07:38.5830
# 4                8457  2018-09-01 00:00:27.3150  2018-09-01 02:21:25.3080
# 5                3326  2018-09-01 00:00:29.3030  2018-09-01 00:55:56.2020
# 6                 233  2018-09-01 00:00:27.2780  2018-09-01 00:04:20.7420
# 7                 285  2018-09-01 00:00:31.4250  2018-09-01 00:05:17.4110
# 8                1127  2018-09-01 00:00:30.9660  2018-09-01 00:19:18.4710
# 9                 423  2018-09-01 00:00:42.1670  2018-09-01 00:07:45.6770
# 10                327  2018-09-01 00:00:45.2480  2018-09-01 00:06:12.2720
# 11                541  2018-09-01 00:00:45.7840  2018-09-01 00:09:47.0470
# ...

# %%
rr = df[(df['start station id'] == 3394.0) | (df['start station id'] == 426.0) | (df['start station id'] == 519.0) | (df['start station id'] == 3590.0)]

# %%
rr.groupby(['start station id', 'starttime'])['starttime'].count()
# Out:
# start station id  starttime
# 426.0             2018-09-01 00:39:28.6360    1
#                   2018-09-01 02:07:42.5890    1
#                   2018-09-01 02:07:43.9730    1
#                   2018-09-01 02:07:47.8400    1
#                   2018-09-01 02:08:15.7550    1
#                   2018-09-01 02:09:09.8920    1
#                   2018-09-01 02:09:37.7840    1
#                   2018-09-01 02:10:03.6490    1
#                   2018-09-01 02:13:32.7530    1
#                   2018-09-01 06:37:34.8980    1
#                   2018-09-01 06:49:41.8960    1
#                   2018-09-01 07:04:51.5620    1
#                   2018-09-01 07:05:15.5060    1
#                   2018-09-01 07:38:16.3300    1
#                   2018-09-01 07:49:01.7730    1
#                   2018-09-01 07:54:00.3160    1
#                   2018-09-01 08:06:11.6280    1
#                   2018-09-01 08:08:06.8260    1
#                   2018-09-01 08:16:46.3500    1
# ...

# %%
df.iloc[-1]
# Out:
# tripduration                                    1354
# starttime                   2018-09-30 14:10:01.1620
# stoptime                    2018-09-30 14:32:36.1280
# start station id                                3601
# start station name         Sterling St & Bedford Ave
# start station latitude                       40.6627
# start station longitude                     -73.9569
# end station id                                  3321
# end station name               Clinton St & Union St
# end station latitude                         40.6831
# end station longitude                       -73.9979
# bikeid                                         26028
# usertype                                  Subscriber
# birth year                                      1981
# gender                                             1
# Name: 1877883, dtype: object

# %%
df['start station id']
# Out:
# 0           252.0
# 1           314.0
# 2          3142.0
# 3           308.0
# 4           345.0
# 5          3142.0
# 6          3526.0
# 7           358.0
# 8           285.0
# 9           319.0
# 10         3509.0
# 11         3077.0
# 12          500.0
# 13         3134.0
# 14          479.0
# 15         3558.0
# 16         3107.0
# 17          350.0
# 18         3384.0
# 19          350.0
# 20          302.0
# 21          236.0
# 22          379.0
# 23          438.0
# 24         3561.0
# 25          261.0
# 26         3002.0
# 27          453.0
# 28         3256.0
# 29         3126.0
#             ...
# 1877854     304.0
# 1877855     151.0
# 1877856     462.0
# 1877857     415.0
# 1877858     402.0
# 1877859    3656.0
# 1877860    3082.0
# 1877861    3578.0
# 1877862    3042.0
# 1877863    3429.0
# 1877864     345.0
# 1877865     345.0
# 1877866    3088.0
# 1877867    3344.0
# 1877868     251.0
# 1877869    3175.0
# 1877870    3092.0
# 1877871    3164.0
# 1877872     143.0
# ...

# %%
l = df[df['start station id'] != df['end station id']][[['start station latitude', 'start station longitude'], ['end station latitude','end station longitude']]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-6cb51ce7f02d> in <module>
# ----> 1 l = df[df['start station id'] != df['end station id']][[['start station latitude', 'start station longitude'], ['end station latitude','end station longitude']]]
#
# ~/PycharmProjects/coursera_python/venv/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/PycharmProjects/coursera_python/venv/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# ...

# %%
l
# Out:
#          start station latitude  start station longitude  \
# 0                     40.732264               -73.998522
# 1                     40.693830               -73.990539
# 2                     40.761227               -73.960940
# 3                     40.713079               -73.998512
# 4                     40.736494               -73.997044
# 5                     40.761227               -73.960940
# 6                     40.774788               -73.912555
# 7                     40.732916               -74.007114
# 8                     40.734546               -73.990741
# 9                     40.711066               -74.009447
# 10                    40.801194               -73.950074
# 11                    40.708771               -73.950953
# 12                    40.762288               -73.983362
# 13                    40.763126               -73.965269
# 14                    40.760193               -73.991255
# ...

# %%
df['start station latitude'][1]
# Out:
# 40.69383

# %%
vincenty((df['start station latitude','start station longitude']), df['location'][1]).miles

# %%
dff
# Out:
#          location_start  location_end
# 0                   NaN           NaN
# 1                   NaN           NaN
# 2                   NaN           NaN
# 3                   NaN           NaN
# 4                   NaN           NaN
# 5                   NaN           NaN
# 6                   NaN           NaN
# 7                   NaN           NaN
# 8                   NaN           NaN
# 9                   NaN           NaN
# 10                  NaN           NaN
# 11                  NaN           NaN
# 12                  NaN           NaN
# 13                  NaN           NaN
# 14                  NaN           NaN
# 15                  NaN           NaN
# 16                  NaN           NaN
# 17                  NaN           NaN
# 18                  NaN           NaN
# 19                  NaN           NaN
# 20                  NaN           NaN
# 21                  NaN           NaN
# 22                  NaN           NaN
# 23                  NaN           NaN
# ...

# %%
r = list(zip(l['start station latitude'], l['start station longitude']))

# %%
df[df['start station name'] == df['end station name']].shape

# %%
r
# Out:
# [(40.73226398, -73.99852205),
#  (40.69383, -73.990539),
#  (40.761227399999996, -73.96094022),
#  (40.71307916, -73.99851193),
#  (40.73649403, -73.99704374),
#  (40.761227399999996, -73.96094022),
#  (40.7747878, -73.91255509999999),
#  (40.73291553, -74.00711384),
#  (40.73454567, -73.99074142),
#  (40.711065999999995, -74.009447),
#  (40.8011939, -73.9500739),
#  (40.70877084, -73.95095259),
#  (40.76228826, -73.98336183),
#  (40.76312584, -73.96526895),
#  (40.76019252, -73.9912551),
#  (40.6794388, -73.96804379999999),
#  (40.72311651, -73.95212324),
#  (40.71559509, -73.9870295),
#  (40.678724200000005, -73.99599099),
#  (40.71559509, -73.9870295),
#  (40.72082834, -73.97793172),
#  (40.7284186, -73.98713956),
#  (40.749156, -73.9916),
#  (40.72779126, -73.98564945),
#  (40.69474881, -73.98362464),
#  (40.711512, -74.01575600000001),
#  (40.74475148, -73.99915362),
#  (40.7277140777778, -74.01129573583603),
#  (40.74718234, -73.9432635),
#  (40.710451, -73.960876),
# ...

# %%
(l['start station latitude'], l['start station longitude'])
# Out:
# (0          40.732264
#  1          40.693830
#  2          40.761227
#  3          40.713079
#  4          40.736494
#  5          40.761227
#  6          40.774788
#  7          40.732916
#  8          40.734546
#  9          40.711066
#  10         40.801194
#  11         40.708771
#  12         40.762288
#  13         40.763126
#  14         40.760193
#  15         40.679439
#  16         40.723117
#  17         40.715595
#  18         40.678724
#  19         40.715595
#  20         40.720828
#  21         40.728419
#  22         40.749156
#  23         40.727791
#  25         40.694749
#  26         40.711512
#  27         40.744751
#  28         40.727714
#  29         40.747182
#  30         40.710451
#               ...
#  1877852    40.726218
#  1877853    40.743453
#  1877854    40.704633
#  1877855    40.722104
#  1877856    40.746920
#  1877857    40.704718
#  1877858    40.740343
#  1877859    40.723077
#  1877860    40.711674
#  1877861    40.674181
# ...

# %%
print(vincenty(list(zip(l['start station latitude'], l['start station longitude'])), list(zip(l['end station latitude'], l['end station longitude']))).miles)
# Out:
# /Users/vananova/PycharmProjects/coursera_python/venv/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Vincenty is deprecated and is going to be removed in geopy 2.0. Use `geopy.distance.geodesic` (or the default `geopy.distance.distance`) instead, which is more accurate and always converges.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-fe8e885a89ce> in <module>
# ----> 1 print(vincenty(list(zip(l['start station latitude'], l['start station longitude'])), list(zip(l['end station latitude'], l['end station longitude']))).miles)
#
# ~/PycharmProjects/coursera_python/venv/lib/python3.7/site-packages/geopy/distance.py in __init__(self, *args, **kwargs)
#     495         self.iterations = kwargs.pop('iterations', 20)
#     496         major, minor, f = self.ELLIPSOID
# ...

# %%
f.sort_values('tripduration', ascending=False)
# Out:
#          tripduration
# bikeid
# 17548   488022.400000
# 28520   417717.000000
# 17431   394605.833333
# 19083   335620.142857
# 18041   103932.100000
# 28053    93774.750000
# 29186    81651.173913
# 34541    67145.750000
# 29402    65119.083333
# 21575    63279.636364
# 27128    61421.222222
# 27911    50466.906977
# 30497    45982.764706
# 26368    45745.920000
# 32258    44411.904762
# 25379    40397.636364
# 17677    40196.777778
# 29328    39940.000000
# 16520    31673.687500
# 34529    30034.928571
# 25630    29925.947368
# 27928    26731.148148
# 30121    26639.777778
# 27745    26383.142857
# 34592    25556.166667
# 33876    24665.024691
# 27122    24618.454545
# 30768    24274.892857
# 34684    22908.525424
# 16701    22869.522388
# ...               ...
# 34539      457.000000
# 34887      456.125000
# 19092      447.818182
# 15623      435.250000
# 33184      422.000000
# 34434      416.666667
# 34502      406.000000
# 29052      404.714286
# 34635      401.800000
# ...
